# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib

# %%
G = nx.DiGraph()
nodes = ["D/W", "F", "S", "A", "P", "M", "N", "J", "K", "G", "H"]
edges = [("F", "D/W"), ("S", "D/W"), ("A", "D/W"), ("P", "D/W"), ("M", "D/W"), ("N", "D/W"), ("J", "D/W"), ("K", "D/W"), ("P", "F"), ("M", "F"), ("N", "F"), ("J", "F"), ("K", "F"), ("M", "J"), ("N", "K"), ("A", "H"), ("H","D/W"), ("H","G"), ("G","D/W")]
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
pos = nx.shell_layout(G)
color_map = []
for node in G:
    if node == "D/W":
        color_map.append('red')
    else: 
        color_map.append('green') 

nx.draw_networkx_nodes(G, pos, node_size=450, node_color=color_map)
nx.draw_networkx_labels(G, pos)
nx.draw_networkx_edges(G, pos, width=0.8)

plt.savefig('causal.png')
plt.show()
